# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

nInst = 50
currentPos = np.zeros(nInst)

def zscore(series):
    return (series - series.mean()) / np.std(series)

def pairs_trading_strategy(prices_A, prices_B, window=50, z_threshold=1.0):
    # Calculate spread and its z-score
    spread = prices_A - prices_B
    z_scores = zscore(spread[-window:])
    current_z_score = z_scores[-1]

    # Trading logic
    if current_z_score > z_threshold:
        return -1, 1  # short A, long B
    elif current_z_score < -z_threshold:
        return 1, -1  # long A, short B
    else:
        return 0, 0  # No position

def mean_reversion_strategy(price_history, window=50, z_threshold=1.0):
    mean = price_history[-window:].mean()
    std = price_history[-window:].std()
    z_score = (price_history[-1] - mean) / std

    if z_score > z_threshold:
        return -1  # Short position
    elif z_score < -z_threshold:
        return 1   # Long position
    else:
        return 0   # No position

def random_forest_predict(prices, n_features=10):
    X = [prices[i:i+n_features] for i in range(len(prices)-n_features)]
    y = prices[n_features:]
    model = RandomForestRegressor()
    model.fit(X, y)
    return model.predict([prices[-n_features:]])[0]

def getMyPosition(prcSoFar):
    global currentPos
    (nins, nt) = prcSoFar.shape

    if nt < 51:  # Need at least 51 data points to compute 50-day mean reversion
        return np.zeros(nins)
    
    # Assume asset 0 and asset 1 are our correlated pair (this is just an example)
    position_A, position_B = pairs_trading_strategy(prcSoFar[0], prcSoFar[1])
    currentPos[0] = position_A
    currentPos[1] = position_B

    # Apply mean reversion strategy for the remaining assets
    for inst in range(2, nins):
        price_history = prcSoFar[inst, :]
        currentPos[inst] = mean_reversion_strategy(price_history)
        
    # Apply Random Forest prediction for asset 0
    next_price = random_forest_predict(prcSoFar[0])
    if next_price > prcSoFar[0, -1]:
        currentPos[0] = 1
    else:
        currentPos[0] = -1
        
    return currentPos

# %%
import numpy as np
import pandas as pd
# from teamName import getMyPosition as getPosition

nInst = 0
nt = 0
commRate = 0.0010
dlrPosLimit = 10000

def loadPrices(fn):
    global nt, nInst
    #df=pd.read_csv(fn, sep='\s+', names=cols, header=None, index_col=0)
    df=pd.read_csv(fn, sep='\s+', header=None, index_col=None)
    nt, nInst = df.values.shape
    return (df.values).T

pricesFile="./prices.txt"
prcAll = loadPrices(pricesFile)
print ("Loaded %d instruments for %d days" % (nInst, nt))

currentPos = np.zeros(nInst)

def calcPL(prcHist):
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_,nt) = prcHist.shape
    for t in range(1,251): 
        prcHistSoFar = prcHist[:,:t]
        newPosOrig = getMyPosition(prcHistSoFar)
        curPrices = prcHistSoFar[:,-1] #prcHist[:,t-1]
        posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
        clipPos = np.clip(newPosOrig, -posLimits, posLimits)
        newPos = np.array([np.trunc(x) for x in clipPos])
        deltaPos = newPos - curPos
        dvolumes = curPrices * np.abs(deltaPos)
        dvolume = np.sum(dvolumes)
        totDVolume += dvolume
        comm = dvolume * commRate
        cash -= curPrices.dot(deltaPos) + comm
        curPos = np.array(newPos)
        posValue = curPos.dot(curPrices)
        todayPL = cash + posValue - value
        todayPLL.append(todayPL)
        value = cash + posValue
        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        print ("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" % (t,value, todayPL, totDVolume, ret))
    pll = np.array(todayPLL)
    (plmu,plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(250) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)



(meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
score = meanpl - 0.1*plstd
print ("=====")
print ("mean(PL): %.1lf" % meanpl)
print ("return: %.5lf" % ret)
print ("StdDev(PL): %.2lf" % plstd)
print ("annSharpe(PL): %.2lf " % sharpe)
print ("totDvolume: %.0lf " % dvol)
print ("Score: %.2lf" % score)
# Out:
# Loaded 50 instruments for 250 days
# Day 1 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# ---------------------------------------------------------------------------
# TypingError                               Traceback (most recent call last)
# <ipython-input-74-d67edd6c3241> in <module>
#      61
#      62
# ---> 63 (meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
#      64 score = meanpl - 0.1*plstd
#      65 print ("=====")
#
# <ipython-input-74-d67edd6c3241> in calcPL(prcHist)
#      32     for t in range(1,251):
#      33         prcHistSoFar = prcHist[:,:t]
# ---> 34         newPosOrig = getMyPosition(prcHistSoFar)
#      35         curPrices = prcHistSoFar[:,-1] #prcHist[:,t-1]
#      36         posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
#
# <ipython-input-73-0012eb514780> in getMyPosition(prcSoFar)
#      53
#      54     # Train your model
# ---> 55     model.fit(data)
#      56
#      57     # Predict future returns for each instrument
#
# ...

# %% [markdown]
# ## Find correlaiton and draw dendogram

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

data = pd.read_csv("./prices.txt", sep='\s+', header=None, index_col=None)
corr_matrix = data.corr()

# Set a threshold for high correlation, for example 0.8
threshold = 0.8

# Create a mask for the diagonal and upper triangle of the correlation matrix
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

# Filter the correlation matrix
high_corr = corr_matrix[(corr_matrix.abs() > threshold) & ~mask]

# Identify pairs of instruments with high correlation
high_corr_pairs = high_corr.stack().index.tolist()

# Print the pairs of instruments with high correlation
# for pair in high_corr_pairs:
#     print(pair)

# %%
import scipy.cluster.hierarchy as sch
import seaborn as sns
import matplotlib.pyplot as plt

# Perform hierarchical clustering on the correlation matrix
linkage_matrix = sch.linkage(corr_matrix, method='ward')

# Visualize the clustering results as a dendrogram
plt.figure(figsize=(15, 10))
dendrogram = sch.dendrogram(linkage_matrix, labels=corr_matrix.columns, leaf_rotation=90)

# Show the plot
plt.show()

# %% [markdown]
# ## Create model

# %%
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor

models = [RandomForestRegressor(random_state=0, n_estimators=100),
          ExtraTreesRegressor(random_state=0, n_estimators=100)]

# %% [markdown]
# ## Apply MLforecast

# %%
from numba import njit

@njit
def Diff(x, lag):
    x2 = np.full_like(x, np.nan)
    for i in range(lag, len(x)):
        x2[i] = x[i] - x[i-lag]
    return x2

# %%
# lag_transforms = {
#     1: [(lambda series: rolling_mean(series, 3), ()),
#         (lambda series: rolling_mean(series, 7), ()),
#         (lambda series: rolling_mean(series, 28), ()),
#         (Diff(1), ()),
#         (Diff(7), ())]
# }

# %%
pricesFile="./prices.txt"
prcAll = loadPrices(pricesFile)
cash = 0
curPos = np.zeros(nInst)
totDVolume = 0
totDVolumeSignal = 0
totDVolumeRandom = 0
value = 0
todayPLL = []
(_,nt) = prcAll.shape
for t in range(1,251): 
        prcHistSoFar = prcAll[:,:t]
#         if nt < 2:
#             return np.zeros(nins)

            # Transform your data into a DataFrame
        (nins, nt) = prcHistSoFar.shape
        data = pd.DataFrame(prcHistSoFar.T, columns=[f'instrument_{i}' for i in range(1, nins+1)])
print(data.head())
# Out:
#    instrument_1  instrument_2  instrument_3  instrument_4  instrument_5  \
# 0         60.17         10.11         40.89         33.32         57.00
# 1         59.99         10.08         40.91         33.31         57.71
# 2         59.66         10.23         41.71         33.34         57.18
# 3         59.38         10.22         41.81         33.33         57.42
# 4         59.21         10.20         42.12         33.31         57.10
#
#    instrument_6  instrument_7  instrument_8  instrument_9  instrument_10  ...  \
# 0         40.71         55.13         43.16         32.26          39.65  ...
# 1         40.36         54.57         43.77         32.18          39.62  ...
# 2         40.59         54.54         43.60         32.06          39.71  ...
# 3         40.06         55.39         43.45         31.99          39.73  ...
# 4         40.15         55.26         43.17         32.01          39.87  ...
#
# ...

# %%
# from window_ops import rolling_mean
# from .windows import PyMouse, PyMouseEvent
from mlforecast import MLForecast

def Rolling(series, window_size):
    return series.rolling(window=window_size).mean()

model = MLForecast(models=models,
                   freq='D',
                   lags=[1,7,14],
                   lag_transforms={
                       1: [(rolling_mean, 3), (rolling_mean, 7), (rolling_mean, 28), (diff, 1), (diff, 7)],
                   },
                   date_features=['dayofweek'],
                   num_threads=6)

# %%
import numpy as np
from mlforecast import MLForecast
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
from numba import njit, float64, int64

nInst = 50
currentPos = np.zeros(nInst)

# Define your custom rolling mean function
def rolling_mean(series, window_size):
    return series.rolling(window=window_size).mean()

# Define your custom Diff function
@njit(float64[:](float64[:], int64))
def Diff(x, lag):
    n = len(x)
    x2 = np.empty(n, dtype=float64)
    for i in range(n):
        if i < lag:
            x2[i] = np.nan
        else:
            x2[i] = x[i] - x[i-lag]
    return x2

def getMyPosition(prcSoFar):
    global currentPos
    (nins, nt) = prcSoFar.shape
    if nt < 2:
        return np.zeros(nins)

    # Transform your data into a DataFrame
    data = pd.DataFrame({
        'unique_id': np.repeat(np.arange(1, nins+1), nt),
        'ds': np.tile(np.arange(1, nt+1), nins),
        'y': prcSoFar.flatten()
    })

    # Initialize your model
    models = [RandomForestRegressor() for _ in range(nins)]
    model = MLForecast(models=models,
                       lags=[1,7,14],
                       lag_transforms={
                           1: [(rolling_mean, (3,)),
                               (rolling_mean, (7,)),
                               (rolling_mean, (28,)),
                               (lambda x: Diff(np.array(x, dtype=float64), 1), ()),
                               (lambda x: Diff(np.array(x, dtype=float64), 7), ())]
                       },
                       num_threads=6)

    # Train your model
    model.fit(data)

    # Predict future returns for each instrument
    forecast = model.predict(steps_ahead=1)

    # Update your positions based on the predicted returns
    lastRet = forecast['y_pred'].values
    rpos = np.array([int(x) for x in 2000000 * lastRet / prcSoFar[:, -1]])
    currentPos = np.array([int(x) for x in currentPos + rpos])

    return currentPos

# %%
data
# Out:
#      instrument_1  instrument_2  instrument_3  instrument_4  instrument_5  \
# 0           60.17         10.11         40.89         33.32         57.00
# 1           59.99         10.08         40.91         33.31         57.71
# 2           59.66         10.23         41.71         33.34         57.18
# 3           59.38         10.22         41.81         33.33         57.42
# 4           59.21         10.20         42.12         33.31         57.10
# ..            ...           ...           ...           ...           ...
# 245         63.29          9.96         41.77         32.15         57.24
# 246         63.74          9.95         41.70         32.10         57.52
# 247         63.44          9.90         41.88         32.08         57.67
# 248         63.18          9.84         42.40         32.07         57.55
# 249         63.32          9.83         42.25         32.05         57.74
#
#      instrument_6  instrument_7  instrument_8  instrument_9  instrument_10  \
# ...
