# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor

nInst = 50
currentPos = np.zeros(nInst)

def zscore(series):
    return (series - series.mean()) / np.std(series)

def pairs_trading_strategy(prices_A, prices_B, window=50, z_threshold=1.0):
    # Calculate spread and its z-score
    spread = prices_A - prices_B
    z_scores = zscore(spread[-window:])
    current_z_score = z_scores[-1]

    # Trading logic
    if current_z_score > z_threshold:
        return -1, 1  # short A, long B
    elif current_z_score < -z_threshold:
        return 1, -1  # long A, short B
    else:
        return 0, 0  # No position

def mean_reversion_strategy(price_history, window=50, z_threshold=1.0):
    mean = price_history[-window:].mean()
    std = price_history[-window:].std()
    z_score = (price_history[-1] - mean) / std

    if z_score > z_threshold:
        return -1  # Short position
    elif z_score < -z_threshold:
        return 1   # Long position
    else:
        return 0   # No position

def random_forest_predict(prices, n_features=10):
    X = [prices[i:i+n_features] for i in range(len(prices)-n_features)]
    y = prices[n_features:]
    model = RandomForestRegressor()
    model.fit(X, y)
    return model.predict([prices[-n_features:]])[0]

def getMyPosition(prcSoFar):
    global currentPos
    (nins, nt) = prcSoFar.shape

    if nt < 51:  # Need at least 51 data points to compute 50-day mean reversion
        return np.zeros(nins)
    
    # Assume asset 0 and asset 1 are our correlated pair (this is just an example)
    position_A, position_B = pairs_trading_strategy(prcSoFar[0], prcSoFar[1])
    currentPos[0] = position_A
    currentPos[1] = position_B

    # Apply mean reversion strategy for the remaining assets
    for inst in range(2, nins):
        price_history = prcSoFar[inst, :]
        currentPos[inst] = mean_reversion_strategy(price_history)
        
    # Apply Random Forest prediction for asset 0
    next_price = random_forest_predict(prcSoFar[0])
    if next_price > prcSoFar[0, -1]:
        currentPos[0] = 1
    else:
        currentPos[0] = -1
        
    return currentPos

# %%
import numpy as np
import pandas as pd
# from teamName import getMyPosition as getPosition

nInst = 0
nt = 0
commRate = 0.0010
dlrPosLimit = 10000

def loadPrices(fn):
    global nt, nInst
    #df=pd.read_csv(fn, sep='\s+', names=cols, header=None, index_col=0)
    df=pd.read_csv(fn, sep='\s+', header=None, index_col=None)
    nt, nInst = df.values.shape
    return (df.values).T

pricesFile="./prices.txt"
prcAll = loadPrices(pricesFile)
print ("Loaded %d instruments for %d days" % (nInst, nt))

currentPos = np.zeros(nInst)

def calcPL(prcHist):
    cash = 0
    curPos = np.zeros(nInst)
    totDVolume = 0
    totDVolumeSignal = 0
    totDVolumeRandom = 0
    value = 0
    todayPLL = []
    (_,nt) = prcHist.shape
    for t in range(1,251): 
        prcHistSoFar = prcHist[:,:t]
        newPosOrig = getMyPosition(prcHistSoFar)
        curPrices = prcHistSoFar[:,-1] #prcHist[:,t-1]
        posLimits = np.array([int(x) for x in dlrPosLimit / curPrices])
        clipPos = np.clip(newPosOrig, -posLimits, posLimits)
        newPos = np.array([np.trunc(x) for x in clipPos])
        deltaPos = newPos - curPos
        dvolumes = curPrices * np.abs(deltaPos)
        dvolume = np.sum(dvolumes)
        totDVolume += dvolume
        comm = dvolume * commRate
        cash -= curPrices.dot(deltaPos) + comm
        curPos = np.array(newPos)
        posValue = curPos.dot(curPrices)
        todayPL = cash + posValue - value
        todayPLL.append(todayPL)
        value = cash + posValue
        ret = 0.0
        if (totDVolume > 0):
            ret = value / totDVolume
        print ("Day %d value: %.2lf todayPL: $%.2lf $-traded: %.0lf return: %.5lf" % (t,value, todayPL, totDVolume, ret))
    pll = np.array(todayPLL)
    (plmu,plstd) = (np.mean(pll), np.std(pll))
    annSharpe = 0.0
    if (plstd > 0):
        annSharpe = np.sqrt(250) * plmu / plstd
    return (plmu, ret, plstd, annSharpe, totDVolume)



(meanpl, ret, plstd, sharpe, dvol) = calcPL(prcAll)
score = meanpl - 0.1*plstd
print ("=====")
print ("mean(PL): %.1lf" % meanpl)
print ("return: %.5lf" % ret)
print ("StdDev(PL): %.2lf" % plstd)
print ("annSharpe(PL): %.2lf " % sharpe)
print ("totDvolume: %.0lf " % dvol)
print ("Score: %.2lf" % score)
# Out:
# Loaded 50 instruments for 250 days
# Day 1 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 2 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 3 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 4 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 5 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 6 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 7 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 8 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 9 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 10 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 11 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 12 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 13 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 14 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 15 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 16 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 17 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 18 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 19 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 20 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 21 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 22 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 23 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 24 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 25 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 26 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 27 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 28 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 29 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 30 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 31 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 32 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 33 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 34 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 35 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 36 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 37 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 38 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 39 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 40 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 41 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 42 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 43 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 44 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 45 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 46 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 47 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 48 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 49 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 50 value: 0.00 todayPL: $0.00 $-traded: 0 return: 0.00000
# Day 51 value: -1.24 todayPL: $-1.24 $-traded: 1244 return: -0.00100
# Day 52 value: -0.77 todayPL: $0.48 $-traded: 1589 return: -0.00048
# Day 53 value: 0.94 todayPL: $1.71 $-traded: 1930 return: 0.00049
# Day 54 value: 0.07 todayPL: $-0.87 $-traded: 2173 return: 0.00003
# Day 55 value: 0.37 todayPL: $0.30 $-traded: 2559 return: 0.00015
# Day 56 value: 0.08 todayPL: $-0.29 $-traded: 2906 return: 0.00003
# Day 57 value: -3.02 todayPL: $-3.10 $-traded: 3287 return: -0.00092
# Day 58 value: -8.32 todayPL: $-5.30 $-traded: 3611 return: -0.00230
# Day 59 value: -9.16 todayPL: $-0.84 $-traded: 3870 return: -0.00237
# Day 60 value: -10.77 todayPL: $-1.61 $-traded: 4253 return: -0.00253
# Day 61 value: -10.84 todayPL: $-0.07 $-traded: 4429 return: -0.00245
# Day 62 value: -10.71 todayPL: $0.13 $-traded: 4732 return: -0.00226
# Day 63 value: -12.30 todayPL: $-1.59 $-traded: 4950 return: -0.00248
# Day 64 value: -15.17 todayPL: $-2.87 $-traded: 5067 return: -0.00299
# Day 65 value: -13.27 todayPL: $1.90 $-traded: 5458 return: -0.00243
# Day 66 value: -15.17 todayPL: $-1.90 $-traded: 5728 return: -0.00265
# Day 67 value: -16.11 todayPL: $-0.94 $-traded: 5945 return: -0.00271
# Day 68 value: -14.51 todayPL: $1.59 $-traded: 6323 return: -0.00230
# Day 69 value: -12.63 todayPL: $1.88 $-traded: 6579 return: -0.00192
# Day 70 value: -12.46 todayPL: $0.17 $-traded: 6965 return: -0.00179
# Day 71 value: -10.29 todayPL: $2.17 $-traded: 7518 return: -0.00137
# Day 72 value: -9.49 todayPL: $0.80 $-traded: 8051 return: -0.00118
# Day 73 value: -9.14 todayPL: $0.35 $-traded: 8620 return: -0.00106
# Day 74 value: -8.68 todayPL: $0.46 $-traded: 8911 return: -0.00097
# Day 75 value: -7.88 todayPL: $0.80 $-traded: 9403 return: -0.00084
# Day 76 value: -9.29 todayPL: $-1.40 $-traded: 9675 return: -0.00096
# Day 77 value: -9.33 todayPL: $-0.04 $-traded: 10050 return: -0.00093
# Day 78 value: -12.37 todayPL: $-3.04 $-traded: 10341 return: -0.00120
# Day 79 value: -14.05 todayPL: $-1.68 $-traded: 10450 return: -0.00134
# Day 80 value: -16.45 todayPL: $-2.40 $-traded: 10585 return: -0.00155
# Day 81 value: -18.56 todayPL: $-2.10 $-traded: 10656 return: -0.00174
# Day 82 value: -18.00 todayPL: $0.56 $-traded: 10808 return: -0.00167
# Day 83 value: -17.83 todayPL: $0.17 $-traded: 11255 return: -0.00158
# Day 84 value: -18.58 todayPL: $-0.75 $-traded: 11718 return: -0.00159
# Day 85 value: -18.22 todayPL: $0.36 $-traded: 12052 return: -0.00151
# Day 86 value: -15.52 todayPL: $2.70 $-traded: 12305 return: -0.00126
# Day 87 value: -17.30 todayPL: $-1.77 $-traded: 12599 return: -0.00137
# Day 88 value: -17.50 todayPL: $-0.20 $-traded: 13027 return: -0.00134
# Day 89 value: -20.17 todayPL: $-2.67 $-traded: 13357 return: -0.00151
# Day 90 value: -19.42 todayPL: $0.74 $-traded: 13953 return: -0.00139
# Day 91 value: -18.79 todayPL: $0.64 $-traded: 14295 return: -0.00131
# Day 92 value: -17.94 todayPL: $0.85 $-traded: 14826 return: -0.00121
# Day 93 value: -17.52 todayPL: $0.41 $-traded: 15105 return: -0.00116
# Day 94 value: -17.89 todayPL: $-0.37 $-traded: 15501 return: -0.00115
# Day 95 value: -15.19 todayPL: $2.70 $-traded: 15972 return: -0.00095
# Day 96 value: -14.95 todayPL: $0.24 $-traded: 16168 return: -0.00092
# Day 97 value: -15.98 todayPL: $-1.04 $-traded: 16535 return: -0.00097
# Day 98 value: -18.32 todayPL: $-2.34 $-traded: 17013 return: -0.00108
# Day 99 value: -19.14 todayPL: $-0.81 $-traded: 17307 return: -0.00111
# Day 100 value: -21.02 todayPL: $-1.89 $-traded: 17503 return: -0.00120
# Day 101 value: -23.02 todayPL: $-2.00 $-traded: 17632 return: -0.00131
# Day 102 value: -25.41 todayPL: $-2.38 $-traded: 17807 return: -0.00143
# Day 103 value: -25.91 todayPL: $-0.50 $-traded: 17979 return: -0.00144
# Day 104 value: -25.12 todayPL: $0.79 $-traded: 18184 return: -0.00138
# Day 105 value: -25.87 todayPL: $-0.74 $-traded: 18609 return: -0.00139
# Day 106 value: -25.01 todayPL: $0.86 $-traded: 18950 return: -0.00132
# Day 107 value: -27.16 todayPL: $-2.15 $-traded: 19167 return: -0.00142
# Day 108 value: -30.62 todayPL: $-3.46 $-traded: 19402 return: -0.00158
# Day 109 value: -34.21 todayPL: $-3.59 $-traded: 19572 return: -0.00175
# Day 110 value: -38.80 todayPL: $-4.59 $-traded: 19940 return: -0.00195
# Day 111 value: -41.37 todayPL: $-2.57 $-traded: 20299 return: -0.00204
# Day 112 value: -40.42 todayPL: $0.95 $-traded: 20814 return: -0.00194
# Day 113 value: -42.90 todayPL: $-2.47 $-traded: 21087 return: -0.00203
# Day 114 value: -43.85 todayPL: $-0.95 $-traded: 21448 return: -0.00204
# Day 115 value: -45.55 todayPL: $-1.70 $-traded: 21725 return: -0.00210
# Day 116 value: -47.82 todayPL: $-2.28 $-traded: 22192 return: -0.00215
# Day 117 value: -48.74 todayPL: $-0.91 $-traded: 22526 return: -0.00216
# Day 118 value: -50.99 todayPL: $-2.25 $-traded: 22738 return: -0.00224
# Day 119 value: -53.38 todayPL: $-2.39 $-traded: 22966 return: -0.00232
# Day 120 value: -53.03 todayPL: $0.35 $-traded: 23086 return: -0.00230
# Day 121 value: -56.33 todayPL: $-3.31 $-traded: 23254 return: -0.00242
# Day 122 value: -59.57 todayPL: $-3.23 $-traded: 23485 return: -0.00254
# Day 123 value: -66.77 todayPL: $-7.20 $-traded: 23637 return: -0.00282
# Day 124 value: -67.81 todayPL: $-1.05 $-traded: 23823 return: -0.00285
# Day 125 value: -69.25 todayPL: $-1.44 $-traded: 24091 return: -0.00287
# Day 126 value: -71.25 todayPL: $-2.00 $-traded: 24332 return: -0.00293
# Day 127 value: -73.38 todayPL: $-2.12 $-traded: 24506 return: -0.00299
# Day 128 value: -73.37 todayPL: $0.01 $-traded: 24698 return: -0.00297
# Day 129 value: -72.04 todayPL: $1.33 $-traded: 24866 return: -0.00290
# Day 130 value: -73.61 todayPL: $-1.57 $-traded: 25109 return: -0.00293
# Day 131 value: -77.92 todayPL: $-4.31 $-traded: 25298 return: -0.00308
# Day 132 value: -80.05 todayPL: $-2.13 $-traded: 25466 return: -0.00314
# Day 133 value: -81.57 todayPL: $-1.53 $-traded: 25623 return: -0.00318
# Day 134 value: -83.89 todayPL: $-2.32 $-traded: 25793 return: -0.00325
# Day 135 value: -84.15 todayPL: $-0.26 $-traded: 26050 return: -0.00323
# Day 136 value: -85.95 todayPL: $-1.80 $-traded: 26363 return: -0.00326
# Day 137 value: -87.76 todayPL: $-1.81 $-traded: 26482 return: -0.00331
# Day 138 value: -92.47 todayPL: $-4.71 $-traded: 26622 return: -0.00347
# Day 139 value: -95.01 todayPL: $-2.54 $-traded: 26820 return: -0.00354
# Day 140 value: -95.49 todayPL: $-0.48 $-traded: 26964 return: -0.00354
# Day 141 value: -100.54 todayPL: $-5.04 $-traded: 27239 return: -0.00369
# Day 142 value: -103.24 todayPL: $-2.70 $-traded: 27449 return: -0.00376
# Day 143 value: -103.43 todayPL: $-0.19 $-traded: 27639 return: -0.00374
# Day 144 value: -106.80 todayPL: $-3.37 $-traded: 27890 return: -0.00383
# Day 145 value: -103.99 todayPL: $2.81 $-traded: 28251 return: -0.00368
# Day 146 value: -104.05 todayPL: $-0.06 $-traded: 28595 return: -0.00364
# Day 147 value: -107.73 todayPL: $-3.67 $-traded: 28665 return: -0.00376
# Day 148 value: -106.64 todayPL: $1.09 $-traded: 28827 return: -0.00370
# Day 149 value: -107.08 todayPL: $-0.44 $-traded: 28920 return: -0.00370
# Day 150 value: -104.68 todayPL: $2.40 $-traded: 29259 return: -0.00358
# Day 151 value: -102.99 todayPL: $1.69 $-traded: 29622 return: -0.00348
# Day 152 value: -103.36 todayPL: $-0.37 $-traded: 29804 return: -0.00347
# Day 153 value: -103.60 todayPL: $-0.23 $-traded: 29986 return: -0.00345
# Day 154 value: -104.54 todayPL: $-0.94 $-traded: 30321 return: -0.00345
# Day 155 value: -103.35 todayPL: $1.19 $-traded: 30533 return: -0.00338
# Day 156 value: -103.36 todayPL: $-0.01 $-traded: 30970 return: -0.00334
# Day 157 value: -105.58 todayPL: $-2.22 $-traded: 31161 return: -0.00339
# Day 158 value: -105.23 todayPL: $0.35 $-traded: 31350 return: -0.00336
# Day 159 value: -104.98 todayPL: $0.25 $-traded: 31690 return: -0.00331
# Day 160 value: -105.69 todayPL: $-0.71 $-traded: 31983 return: -0.00330
# Day 161 value: -104.38 todayPL: $1.32 $-traded: 32477 return: -0.00321
# Day 162 value: -103.20 todayPL: $1.18 $-traded: 32758 return: -0.00315
# Day 163 value: -103.97 todayPL: $-0.77 $-traded: 32881 return: -0.00316
# Day 164 value: -104.59 todayPL: $-0.62 $-traded: 33387 return: -0.00313
# Day 165 value: -106.67 todayPL: $-2.08 $-traded: 33688 return: -0.00317
# Day 166 value: -108.12 todayPL: $-1.45 $-traded: 33816 return: -0.00320
# Day 167 value: -108.47 todayPL: $-0.36 $-traded: 34033 return: -0.00319
# Day 168 value: -109.30 todayPL: $-0.83 $-traded: 34222 return: -0.00319
# Day 169 value: -109.58 todayPL: $-0.28 $-traded: 34581 return: -0.00317
# Day 170 value: -108.19 todayPL: $1.39 $-traded: 34910 return: -0.00310
# Day 171 value: -108.83 todayPL: $-0.64 $-traded: 35194 return: -0.00309
# Day 172 value: -109.24 todayPL: $-0.41 $-traded: 35482 return: -0.00308
# Day 173 value: -108.24 todayPL: $1.01 $-traded: 35785 return: -0.00302
# Day 174 value: -109.28 todayPL: $-1.04 $-traded: 36209 return: -0.00302
# Day 175 value: -110.56 todayPL: $-1.28 $-traded: 36583 return: -0.00302
# Day 176 value: -110.56 todayPL: $0.00 $-traded: 36948 return: -0.00299
# Day 177 value: -112.26 todayPL: $-1.71 $-traded: 37354 return: -0.00301
# Day 178 value: -112.02 todayPL: $0.24 $-traded: 37911 return: -0.00295
# Day 179 value: -114.63 todayPL: $-2.61 $-traded: 38283 return: -0.00299
# Day 180 value: -115.83 todayPL: $-1.19 $-traded: 38745 return: -0.00299
# Day 181 value: -116.31 todayPL: $-0.49 $-traded: 39151 return: -0.00297
# Day 182 value: -113.50 todayPL: $2.82 $-traded: 39505 return: -0.00287
# Day 183 value: -114.96 todayPL: $-1.47 $-traded: 39973 return: -0.00288
# Day 184 value: -115.32 todayPL: $-0.36 $-traded: 40421 return: -0.00285
# Day 185 value: -118.63 todayPL: $-3.31 $-traded: 40614 return: -0.00292
# Day 186 value: -118.94 todayPL: $-0.31 $-traded: 40952 return: -0.00290
# Day 187 value: -119.29 todayPL: $-0.34 $-traded: 41397 return: -0.00288
# Day 188 value: -120.54 todayPL: $-1.26 $-traded: 41582 return: -0.00290
# Day 189 value: -121.07 todayPL: $-0.53 $-traded: 41788 return: -0.00290
# Day 190 value: -119.59 todayPL: $1.47 $-traded: 42094 return: -0.00284
# Day 191 value: -120.07 todayPL: $-0.48 $-traded: 42604 return: -0.00282
# Day 192 value: -121.43 todayPL: $-1.36 $-traded: 42822 return: -0.00284
# Day 193 value: -122.19 todayPL: $-0.76 $-traded: 43184 return: -0.00283
# Day 194 value: -121.93 todayPL: $0.26 $-traded: 43541 return: -0.00280
# Day 195 value: -119.98 todayPL: $1.95 $-traded: 43752 return: -0.00274
# Day 196 value: -118.90 todayPL: $1.08 $-traded: 44142 return: -0.00269
# Day 197 value: -118.28 todayPL: $0.63 $-traded: 44566 return: -0.00265
# Day 198 value: -118.59 todayPL: $-0.31 $-traded: 44919 return: -0.00264
# Day 199 value: -117.92 todayPL: $0.67 $-traded: 45420 return: -0.00260
# Day 200 value: -117.54 todayPL: $0.38 $-traded: 45752 return: -0.00257
# Day 201 value: -117.28 todayPL: $0.26 $-traded: 45919 return: -0.00255
# Day 202 value: -118.20 todayPL: $-0.93 $-traded: 46474 return: -0.00254
# Day 203 value: -119.77 todayPL: $-1.56 $-traded: 46858 return: -0.00256
# Day 204 value: -120.02 todayPL: $-0.25 $-traded: 47125 return: -0.00255
# Day 205 value: -119.95 todayPL: $0.07 $-traded: 47680 return: -0.00252
# Day 206 value: -122.39 todayPL: $-2.44 $-traded: 48093 return: -0.00254
# Day 207 value: -123.16 todayPL: $-0.77 $-traded: 48369 return: -0.00255
# Day 208 value: -125.64 todayPL: $-2.49 $-traded: 48605 return: -0.00259
# Day 209 value: -127.17 todayPL: $-1.53 $-traded: 48913 return: -0.00260
# Day 210 value: -127.76 todayPL: $-0.59 $-traded: 49125 return: -0.00260
# Day 211 value: -129.71 todayPL: $-1.95 $-traded: 49330 return: -0.00263
# Day 212 value: -129.44 todayPL: $0.27 $-traded: 49726 return: -0.00260
# Day 213 value: -131.87 todayPL: $-2.43 $-traded: 50178 return: -0.00263
# Day 214 value: -132.88 todayPL: $-1.01 $-traded: 50586 return: -0.00263
# Day 215 value: -132.87 todayPL: $0.00 $-traded: 50914 return: -0.00261
# Day 216 value: -135.28 todayPL: $-2.41 $-traded: 51133 return: -0.00265
# Day 217 value: -135.31 todayPL: $-0.02 $-traded: 51467 return: -0.00263
# Day 218 value: -135.41 todayPL: $-0.11 $-traded: 52033 return: -0.00260
# Day 219 value: -137.20 todayPL: $-1.79 $-traded: 52225 return: -0.00263
# Day 220 value: -137.02 todayPL: $0.18 $-traded: 52510 return: -0.00261
# Day 221 value: -139.40 todayPL: $-2.38 $-traded: 52821 return: -0.00264
# Day 222 value: -140.18 todayPL: $-0.78 $-traded: 52921 return: -0.00265
# Day 223 value: -142.19 todayPL: $-2.01 $-traded: 53107 return: -0.00268
# Day 224 value: -143.29 todayPL: $-1.11 $-traded: 53434 return: -0.00268
# Day 225 value: -142.95 todayPL: $0.35 $-traded: 53728 return: -0.00266
# Day 226 value: -141.06 todayPL: $1.89 $-traded: 54086 return: -0.00261
# Day 227 value: -142.93 todayPL: $-1.87 $-traded: 54369 return: -0.00263
# Day 228 value: -144.55 todayPL: $-1.62 $-traded: 54758 return: -0.00264
# Day 229 value: -147.51 todayPL: $-2.97 $-traded: 55195 return: -0.00267
# Day 230 value: -149.09 todayPL: $-1.58 $-traded: 55565 return: -0.00268
# Day 231 value: -147.96 todayPL: $1.13 $-traded: 55911 return: -0.00265
# Day 232 value: -148.76 todayPL: $-0.80 $-traded: 56132 return: -0.00265
# Day 233 value: -146.93 todayPL: $1.83 $-traded: 56487 return: -0.00260
# Day 234 value: -147.33 todayPL: $-0.40 $-traded: 56822 return: -0.00259
# Day 235 value: -146.83 todayPL: $0.50 $-traded: 57181 return: -0.00257
# Day 236 value: -147.55 todayPL: $-0.72 $-traded: 57528 return: -0.00256
# Day 237 value: -145.21 todayPL: $2.34 $-traded: 58025 return: -0.00250
# Day 238 value: -146.28 todayPL: $-1.08 $-traded: 58595 return: -0.00250
# Day 239 value: -146.23 todayPL: $0.06 $-traded: 59118 return: -0.00247
# Day 240 value: -145.25 todayPL: $0.98 $-traded: 59558 return: -0.00244
# Day 241 value: -145.93 todayPL: $-0.68 $-traded: 59759 return: -0.00244
# Day 242 value: -147.00 todayPL: $-1.07 $-traded: 60048 return: -0.00245
# Day 243 value: -147.54 todayPL: $-0.54 $-traded: 60349 return: -0.00244
# Day 244 value: -148.41 todayPL: $-0.87 $-traded: 60492 return: -0.00245
# Day 245 value: -147.80 todayPL: $0.61 $-traded: 60730 return: -0.00243
# Day 246 value: -149.72 todayPL: $-1.92 $-traded: 60891 return: -0.00246
# Day 247 value: -148.46 todayPL: $1.26 $-traded: 61270 return: -0.00242
# Day 248 value: -148.44 todayPL: $0.02 $-traded: 61605 return: -0.00241
# Day 249 value: -148.39 todayPL: $0.05 $-traded: 62030 return: -0.00239
# Day 250 value: -148.83 todayPL: $-0.43 $-traded: 62245 return: -0.00239
# =====
# mean(PL): -0.6
# return: -0.00239
# StdDev(PL): 1.48
# annSharpe(PL): -6.37
# totDvolume: 62245
# Score: -0.74
